# %%
import pandas as pd

# %% [markdown]
# ## Importing data using pandas read

# %%
df = pd.read_csv("/home/chinmay/SuperstorePerformanceProject/Data/SuperstoreData.csv")
df.head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2014-103278  2016-02-26  2016-03-02     First Class    CG-53283
# 1       2  CA-2016-132098  2017-06-14  2017-06-21     First Class    CG-24855
# 2       3  CA-2015-118289  2016-05-06  2016-05-08  Standard Class    CG-73113
#
#   Customer Name    Segment        Country     City  ... Postal Code  Region  \
# 0   Kate Taylor  Corporate  United States  Phoenix  ...       39825    West
# 1  Tom Anderson  Corporate  United States  Seattle  ...       26202    West
# 2      Jane Doe  Corporate  United States  Phoenix  ...       27814    West
#
#   Product ID    Category Sub-Category      Product Name    Sales  Quantity  \
# 0   PRD-6289   Furniture       Tables  Conference Table  3021.48         9
# 1   PRD-4708  Technology  Accessories  Accessories Item  4986.74         2
# 2   PRD-7043   Furniture       Chairs   Executive Chair  4600.80         2
#
#    Discount  Profit
# 0      0.50  898.98
# ...

# %% [markdown]
# ## Data Cleaning (Dropping null values, stripping column names and removing any spaces from column names)

# %%
df.dropna(inplace=True)

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df.head(3)
# Out:
#    rowid         orderid   orderdate    shipdate        shipmode customerid  \
# 0      1  CA-2014-103278  2016-02-26  2016-03-02     First Class   CG-53283
# 1      2  CA-2016-132098  2017-06-14  2017-06-21     First Class   CG-24855
# 2      3  CA-2015-118289  2016-05-06  2016-05-08  Standard Class   CG-73113
#
#    customername    segment        country     city  ... postalcode  region  \
# 0   Kate Taylor  Corporate  United States  Phoenix  ...      39825    West
# 1  Tom Anderson  Corporate  United States  Seattle  ...      26202    West
# 2      Jane Doe  Corporate  United States  Phoenix  ...      27814    West
#
#   productid    category sub-category       productname    sales  quantity  \
# 0  PRD-6289   Furniture       Tables  Conference Table  3021.48         9
# 1  PRD-4708  Technology  Accessories  Accessories Item  4986.74         2
# 2  PRD-7043   Furniture       Chairs   Executive Chair  4600.80         2
#
#    discount  profit
# 0      0.50  898.98
# ...

# %% [markdown]
# ## Converting orderdate and shipdate to pandas datetime objects

# %%
df['orderdate'] = pd.to_datetime(df['orderdate'])

# %%
df['shipdate'] = pd.to_datetime(df['shipdate'])

# %%
df.head(3)
# Out:
#    rowid         orderid  orderdate   shipdate        shipmode customerid  \
# 0      1  CA-2014-103278 2016-02-26 2016-03-02     First Class   CG-53283
# 1      2  CA-2016-132098 2017-06-14 2017-06-21     First Class   CG-24855
# 2      3  CA-2015-118289 2016-05-06 2016-05-08  Standard Class   CG-73113
#
#    customername    segment        country     city  ... postalcode  region  \
# 0   Kate Taylor  Corporate  United States  Phoenix  ...      39825    West
# 1  Tom Anderson  Corporate  United States  Seattle  ...      26202    West
# 2      Jane Doe  Corporate  United States  Phoenix  ...      27814    West
#
#   productid    category sub-category       productname    sales  quantity  \
# 0  PRD-6289   Furniture       Tables  Conference Table  3021.48         9
# 1  PRD-4708  Technology  Accessories  Accessories Item  4986.74         2
# 2  PRD-7043   Furniture       Chairs   Executive Chair  4600.80         2
#
#    discount  profit
# 0      0.50  898.98
# 1      0.23 -952.67
# ...

# %% [markdown]
# ## Exporting the clean data to a new csv file

# %%
df.to_csv("/home/chinmay/SuperstorePerformanceProject/Data/SuperstoreCleanData.csv", index=False)
