# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# ## Data Loading

# %%
df = pd.read_csv('/home/chinmay/SuperstoreProject/Data/SuperstoreCleanDataWithSegment.csv', parse_dates=['OrderDate'])

# %% [markdown]
# ## Quick Summary

# %%
print(df.shape)
# Out:
# (1000, 28)

# %%
print(df.dtypes)
# Out:
# RowID                       int64
# OrderID                    object
# OrderDate          datetime64[ns]
# ShipDate                   object
# ShipMode                   object
# CustomerID                 object
# CustomerName               object
# CustomerType               object
# Country                    object
# City                       object
# State                      object
# PostalCode                  int64
# Region                     object
# ProductID                  object
# ProductCategory            object
# SubCategory                object
# ProductName                object
# Sales                     float64
# Quantity                    int64
# Discount                  float64
# Profit                    float64
# Recency                     int64
# Frequency                   int64
# Monetary                  float64
# RScore                      int64
# FScore                      int64
# MScore                      int64
# ...

# %%
df.head()
# Out:
#    RowID         OrderID  OrderDate    ShipDate        ShipMode CustomerID  \
# 0      1  CA-2014-103278 2016-02-26  2016-03-02     First Class   CG-53283
# 1      2  CA-2016-132098 2017-06-14  2017-06-21     First Class   CG-24855
# 2      3  CA-2015-118289 2016-05-06  2016-05-08  Standard Class   CG-73113
# 3      4  CA-2014-188696 2015-05-24  2015-05-26     First Class   CG-98503
# 4      5  CA-2014-177397 2014-11-24  2014-12-08    Second Class   CG-72759
#
#      CustomerName CustomerType        Country          City  ... Quantity  \
# 0     Kate Taylor    Corporate  United States       Phoenix  ...        9
# 1    Tom Anderson    Corporate  United States       Seattle  ...        2
# 2        Jane Doe    Corporate  United States       Phoenix  ...        2
# 3  Sarah Williams  Home Office  United States       Seattle  ...        4
# 4    Chris Wilson     Consumer  United States  Indianapolis  ...        2
#
# ...

# %%
df.describe()
# Out:
#              RowID                   OrderDate    PostalCode        Sales  \
# count  1000.000000                        1000   1000.000000  1000.000000
# mean    500.500000  2016-01-27 08:36:57.600000  53704.321000  2508.127580
# min       1.000000         2014-01-07 00:00:00  10220.000000    10.050000
# 25%     250.750000         2015-02-17 12:00:00  30983.750000  1174.407500
# 50%     500.500000         2016-02-12 00:00:00  52376.000000  2543.540000
# 75%     750.250000         2017-01-18 12:00:00  75073.500000  3772.297500
# max    1000.000000         2017-12-31 00:00:00  99939.000000  4995.710000
# std     288.819436                         NaN  25783.287761  1469.193051
#
#           Quantity     Discount       Profit     Recency    Frequency  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean      5.560000     0.248340   220.233850   700.42800     1.018000
# min       1.000000     0.000000  -973.370000     1.00000     1.000000
# ...

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Sales Distribution

# %%
sns.histplot(df['Sales'], bins = 50, color = '#9e00cf')
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Number of Orders')
# Out:
# Text(0, 0.5, 'Number of Orders')

# %% [markdown]
# ### Profit Distribution

# %%
sns.histplot(df['Profit'], bins = 50, color = '#bf9c00')
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.ylabel('Number of Orders')
# Out:
# Text(0, 0.5, 'Number of Orders')

# %% [markdown]
# ### Box Plots for Sales

# %%
sns.boxplot(data = df, x = 'ProductCategory', y = 'Sales', color = '#9e00cf')
plt.title('Sales by Categories')
plt.xlabel('Categories')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Box Plot for Profits

# %%
sns.boxplot(data = df, x = 'Segment', y = 'Profit', color = '#bf9c00')
plt.title('Profit by Segments')
plt.xlabel('Segments')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ### Categorical Counts

# %%
print(df['ProductCategory'].value_counts())
# Out:
# ProductCategory
# Technology         341
# Office Supplies    338
# Furniture          321
# Name: count, dtype: int64

# %%
print(df['Region'].value_counts())
# Out:
# Region
# West       284
# Central    247
# East       244
# South      225
# Name: count, dtype: int64

# %%
print(df['Segment'].value_counts())
# Out:
# Segment
# At Risk     397
# Loyal       302
# Regular     232
# Champion     69
# Name: count, dtype: int64

# %% [markdown]
# ## Trend Analysis

# %% [markdown]
# ### Monthly Sales Trend

# %%
df['Month'] = df['OrderDate'].dt.to_period('M')

# %%
MonthlySales = df.groupby('Month')['Sales'].sum()

# %%
MonthlySales.plot(figsize=(15,6), color = '#9e00cf')
plt.title('Monthly Sales Trend') 
plt.xlabel('Month') 
plt.ylabel('Sales')
plt.grid()

# %% [markdown]
# ### Monthly Profit Trend

# %%
MonthlyProfit = df.groupby('Month')['Profit'].sum()

# %%
MonthlyProfit.plot(figsize=(15,6), color='#bf9c00')
plt.title('Monthly Profit Trend')
plt.xlabel('Month')
plt.ylabel('Profit')
plt.grid()

# %% [markdown]
# ## Customer Segmentation Visuals

# %% [markdown]
# ### Segment Distribution

# %%
SegmentCounts = df.groupby('Segment')['CustomerID'].nunique()

# %%
SegmentCounts.plot.pie(autopct='%1.1f%%', figsize=(7,7), labeldistance = 0.6, pctdistance = 0.4,
                      colors = ['#fc0303', '#7f02b5', '#0bb502', '#fce803'])
plt.title('Customer Segment Distribution')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Correlation Matrix

# %%
corr = df[['Sales', 'Profit', 'Discount', 'Quantity', 'RScore', 'FScore', 'MScore']].corr()
sns.heatmap(corr, annot=True, cmap='YlGnBu')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Outlier and Anomaly Checks

# %%
df['SalesZ'] = zscore(df['Sales'])

# %%
print('Sales outliers (|z| > 3):', df[abs(df['SalesZ']) > 3].shape[0])
# Out:
# Sales outliers (|z| > 3): 0
