# %% [markdown]
# # Creating Segments in Python

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing the data from CV using read_csv

# %%
df = pd.read_csv('/home/chinmay/SuperstoreProject/Data/SuperstoreCleanData.csv', parse_dates=['OrderDate'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowID            1000 non-null   int64
#  1   OrderID          1000 non-null   object
#  2   OrderDate        1000 non-null   datetime64[ns]
#  3   ShipDate         1000 non-null   object
#  4   ShipMode         1000 non-null   object
#  5   CustomerID       1000 non-null   object
#  6   CustomerName     1000 non-null   object
#  7   CustomerType     1000 non-null   object
#  8   Country          1000 non-null   object
#  9   City             1000 non-null   object
#  10  State            1000 non-null   object
#  11  PostalCode       1000 non-null   int64
#  12  Region           1000 non-null   object
#  13  ProductID        1000 non-null   object
#  14  ProductCategory  1000 non-null   object
#  15  SubCategory      1000 non-null   object
#  16  ProductName      1000 non-null   object
#  17  Sales            1000 non-null   float64
#  18  Quantity         1000 non-null   int64
#  19  Discount         1000 non-null   float64
#  20  Profit           1000 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(14)
# memory usage: 164.2+ KB

# %% [markdown]
# ## Defining most recent order date

# %%
today = df['OrderDate'].max() + pd.Timedelta(days=1)

# %% [markdown]
# ## Creating RFM analysis by grouping customers and calculating recency, frequency and monetary matrices

# %%
rfm = df.groupby('CustomerID').agg({
    'OrderDate': lambda x: (today - x.max()).days,
    'OrderID': 'nunique',
    'Sales': 'sum'
}).rename(columns={'OrderDate': 'Recency', 'OrderID': 'Frequency', 'Sales': 'Monetary'})

# %% [markdown]
# ## Converting the raw values into standardized scores for easier customer segmentation (Scale of 1 to 5)

# %%
rfm['RScore'] = pd.qcut(rfm['Recency'], 5, labels=range(5,0,-1))

# %%
rfm['FScore'] = pd.qcut(rfm['Frequency'].rank(method='first'), 5, labels=range(1,6))

# %%
rfm['MScore'] = pd.qcut(rfm['Monetary'], 5, labels=range(1,6))

# %% [markdown]
# ## Defining function to assign customer segments based on their RFM scores

# %%
def segment(row):
    if row['RScore'] >= 4 and row['FScore'] >= 4 and row['MScore'] >= 4:
        return 'Champion'
    elif row['RScore'] >= 3 and row['FScore'] >= 3:
        return 'Loyal'
    elif row['RScore'] <= 2:
        return 'At Risk'
    else:
        return 'Regular'

# %%
rfm['Segment'] = rfm.apply(segment, axis=1)

# %% [markdown]
# ## Merging the customer segments back into the original dataframe

# %%
df = df.merge(rfm, left_on='CustomerID', right_index=True)

# %%
df.head(20)
# Out:
#     RowID         OrderID  OrderDate    ShipDate        ShipMode CustomerID  \
# 0       1  CA-2014-103278 2016-02-26  2016-03-02     First Class   CG-53283
# 1       2  CA-2016-132098 2017-06-14  2017-06-21     First Class   CG-24855
# 2       3  CA-2015-118289 2016-05-06  2016-05-08  Standard Class   CG-73113
# 3       4  CA-2014-188696 2015-05-24  2015-05-26     First Class   CG-98503
# 4       5  CA-2014-177397 2014-11-24  2014-12-08    Second Class   CG-72759
# 5       6  CA-2017-104165 2015-11-02  2015-11-14    Second Class   CG-72786
# 6       7  CA-2014-112280 2017-03-29  2017-04-01        Same Day   CG-37617
# 7       8  CA-2015-130495 2015-10-03  2015-10-09     First Class   CG-87436
# 8       9  CA-2014-173563 2015-01-24  2015-01-29    Second Class   CG-31134
# 9      10  CA-2015-193850 2014-11-23  2014-11-29        Same Day   CG-94837
# 10     11  CA-2017-128893 2016-10-17  2016-10-25  Standard Class   CG-63857
# 11     12  CA-2017-177236 2016-11-20  2016-12-03  Standard Class   CG-12942
# 12     13  CA-2016-100851 2016-08-14  2016-08-18  Standard Class   CG-41938
# 13     14  CA-2015-191506 2016-10-18  2016-10-27    Second Class   CG-15655
# 14     15  CA-2017-144597 2015-09-24  2015-10-02    Second Class   CG-26762
# 15     16  CA-2016-120379 2016-10-15  2016-10-21  Standard Class   CG-85168
# 16     17  CA-2015-144118 2014-02-17  2014-02-25        Same Day   CG-87640
# 17     18  CA-2014-112156 2014-07-04  2014-07-06  Standard Class   CG-31119
# 18     19  CA-2017-112676 2016-03-16  2016-03-24     First Class   CG-27658
# 19     20  CA-2016-145082 2016-11-01  2016-11-13    Second Class   CG-92515
#
#       CustomerName CustomerType        Country           City  ... Quantity  \
# 0      Kate Taylor    Corporate  United States        Phoenix  ...        9
# 1     Tom Anderson    Corporate  United States        Seattle  ...        2
# 2         Jane Doe    Corporate  United States        Phoenix  ...        2
# 3   Sarah Williams  Home Office  United States        Seattle  ...        4
# 4     Chris Wilson     Consumer  United States   Indianapolis  ...        2
# 5      David Brown  Home Office  United States   Indianapolis  ...        8
# 6     Chris Wilson    Corporate  United States          Miami  ...        7
# 7     Mike Johnson    Corporate  United States         Denver  ...        6
# 8     Mike Johnson    Corporate  United States   Indianapolis  ...        4
# 9       Lisa Davis  Home Office  United States        Chicago  ...       10
# 10        Jane Doe  Home Office  United States    Los Angeles  ...        8
# 11    Amy Martinez    Corporate  United States      Baltimore  ...        1
# 12     Kate Taylor    Corporate  United States        Chicago  ...        6
# 13      John Smith     Consumer  United States       New York  ...        5
# 14    Tom Anderson     Consumer  United States  San Francisco  ...        9
# 15    Chris Wilson    Corporate  United States        Phoenix  ...        8
# 16     David Brown     Consumer  United States        Houston  ...        4
# 17        Jane Doe    Corporate  United States        Phoenix  ...       10
# 18    Chris Wilson    Corporate  United States         Boston  ...        7
# 19    Tom Anderson    Corporate  United States         Dallas  ...        2
#
#     Discount   Profit Recency Frequency Monetary RScore  FScore  MScore  \
# 0       0.50   898.98     675         1  3021.48      3       3       3
# 1       0.23  -952.67     201         1  4986.74      5       1       5
# 2       0.14   410.20     605         1  4600.80      3       4       5
# 3       0.01   260.62     953         1  4689.71      2       5       5
# 4       0.29   943.64    1134         1  4643.75      2       4       5
# 5       0.48   580.18     791         1  2744.42      3       4       3
# 6       0.03  -219.55     278         1  1950.34      5       2       2
# 7       0.41  -192.70     821         1  2245.20      3       5       3
# 8       0.21    69.18    1073         1   590.74      2       2       1
# 9       0.23   396.81    1135         1  2776.76      1       5       3
# 10      0.44   659.44     441         1  1698.34      4       3       2
# 11      0.29   459.17     407         1  1834.81      4       1       2
# 12      0.46   -58.85     505         1  1204.86      4       2       2
# 13      0.42  -346.71     440         1  4089.75      4       1       5
# 14      0.11   -37.78     830         1   949.82      3       1       2
# 15      0.13   253.18     443         1  2027.38      4       5       3
# 16      0.45  -100.04    1414         1  1798.02      1       5       2
# 17      0.43  1273.27    1277         1  4583.89      1       2       5
# 18      0.41   -62.44     656         1  4606.41      3       1       5
# 19      0.33   427.62     426         1  4056.43      4       5       4
#
#      Segment
# 0      Loyal
# 1    Regular
# 2      Loyal
# 3    At Risk
# 4    At Risk
# 5      Loyal
# 6    Regular
# 7      Loyal
# 8    At Risk
# 9    At Risk
# 10     Loyal
# 11   Regular
# 12   Regular
# 13   Regular
# 14   Regular
# 15     Loyal
# 16   At Risk
# 17   At Risk
# 18   Regular
# 19  Champion
#
# [20 rows x 28 columns]

# %% [markdown]
# ## Saving the enhanced dataframe (now containing customer segments) to a CSV file.

# %%
df.to_csv('/home/chinmay/SuperstoreProject/Data/SuperstoreCleanDataWithSegment.csv', index=False)
